# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Create two linearly spaced grids v and w. v should contain 60 points on [0, 1]. w should contain 80 points on [0, 2]. Check lab 1 for details if needed.

# %%
v = np.linspace(0,1,60)
w = np.linspace(0,2,80)

# %% [markdown]
# Create arrays containing sin(𝑣) and exp(−𝑤^2).

# %%
sin = np.array(np.sin(v))
exp = np.array(np.exp(-(w**2)))

# %% [markdown]
# Plot both arrays in different windows.

# %%
sin_plot = plt.plot(v,sin)

# %%
exp_plot = plt.plot(w,exp)

# %% [markdown]
# Add axis labels and titles to a plot.

# %%
plt.xlabel("x axis")
plt.ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')

# %% [markdown]
# Plot both curves on the same plot. Add a legend. Change the 𝑥 axis so that only the range [0, 1] is shown.

# %%
plt.plot(w,exp)
plt.plot(v,sin)
plt.xlim(0, 1)
plt.legend(['sin', 'exp'])

# %% [markdown]
# Plot both curves in different subplots in the same window. Use different linestyles and markers for the different curves
# (such as a thick red dashed line for sin(𝑣) and black crosses for exp(−𝑤2)).

# %%
fig, axes = plt.subplots(2)
axes[0].plot(v, sin, 'r--', linewidth=2)
axes[1].plot(w, exp, 'bx')

# %% [markdown]
# Create a linearly spaced grid for 𝑥 ∈ [0.01, 10]. Plot 𝑥 against 𝑥3 using the
# loglog and semilogx commands.

# %%
d = np.linspace(0.001,10,1000)
plt.semilogx(d, d**3)

# %%
plt.loglog(d, d**3)

# %% [markdown]
# Implement a function add that adds two numbers.

# %%
def adder(a,b):
    return a+b
adder(4,2)
# Out:
# 6

# %% [markdown]
# Implement a function trapezoidal that approximates the integral of the function f on the domain from a to b using N points.

# %%
def trapezoidal(f,a,b,N):
    # trap rule:
    # 1/(N-1)*[fx_1 + fx_2 .... fx_(n-1)]+1/2(N-1)*(fx_0 + fx_n)
    
    h = (b-a)/(N-1)    
    x = np.linspace(a,b,N)    
    f_x = np.array(eval(f))    
    area = (h/2)*(f_x[0]+ f_x[-1] + 2*np.sum(f_x[1:-1]))    
    return area
    
trapezoidal("x**2",0,10,10)
# Out:
# 335.3909465020576
